# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.linspace(0,5,11)

# %%
y = x**2

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows = 1,ncols=2)
#axes.plot(x,y)

# %%
fig,axes = plt.subplots(nrows = 3,ncols=3)

# %%
fig,axes = plt.subplots(nrows = 3,ncols=3)
plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows = 1,ncols=2)

# %%
#axes object is just a array
type(axes)
# Out:
# numpy.ndarray

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
fig,axes = plt.subplots(nrows = 1,ncols = 2)
axes[0].plot(x,y)## indexing is possible cause array
axes[1].set_title('second')
plt.tight_layout()

# %% [markdown]
# # FIGURE SIZE AND DPI

# %%
f = plt.figure(figsize=(4,2)) #width, hieght by inches 

ax = f.add_axes([0,0,1,1])

# %%
f,ax = plt.subplots(nrows = 2,ncols = 1, figsize = (4,2)) #length, width
plt.tight_layout()

# %%
#practice
import pandas as pd
import numpy as np

# %%
d = {'A':[0,1,2,3],'B':[4,5,6,7],'C':[8,9,10,11]}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#    A  B   C
# 0  0  4   8
# 1  1  5   9
# 2  2  6  10
# 3  3  7  11

# %%
##df.to_csv()###

# %%
f.savefig('Mygraph.png',dpi = 200)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label = 'x sq')
ax.plot(x,x**3, label= 'x cu')

ax.legend(loc = 0)#location code to find

# %% [markdown]
# # MATPLOTLIB 3

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])

axes.plot(x,y,color='orange',linewidth=3,alpha =1,linestyle='--',marker ='o',markersize=10)#rgb hex code maker for custon colors#alpha defines transparency#linewidth or lw

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])

axes.plot(x,y,color='orange',linewidth=3,alpha =1,linestyle='--',marker ='o',markersize=10,markerfacecolor='yellow')

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green"); #above graph
