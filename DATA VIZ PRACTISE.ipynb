# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('df3')
# %matplotlib inline
import seaborn as sns

# %%
sns.set_style()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a',y='b',color='r',edgecolor='black',figsize=(12,3),s=70)
plt.xlim(-0.2,1.2)
plt.ylim(-0.2,1.2)
#### i couldn't control the size
# Out:
# (-0.2, 1.2)

# %%
df3['a'].plot.hist(color='blue',ec='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.set_style(rc='ggplot')
df3['a'].plot.hist(bins=30)#####solution down under
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\DELLLA~1\AppData\Local\Temp/ipykernel_28716/1759497149.py in <module>
# ----> 1 sns.set_style(rc='ggplot')
#       2 df3['a'].plot.hist(bins=30)
#
# ~\anaconda3\lib\site-packages\seaborn\rcmod.py in set_style(style, rc)
#     335
#     336     """
# --> 337     style_object = axes_style(style, rc)
#     338     mpl.rcParams.update(style_object)
#     339
#
# ~\anaconda3\lib\site-packages\seaborn\rcmod.py in axes_style(style, rc)
#     298     # Override these settings with the provided rc dictionary
#     299     if rc is not None:
# --> 300         rc = {k: v for k, v in rc.items() if k in _style_keys}
#     301         style_dict.update(rc)
#     302
#
# AttributeError: 'str' object has no attribute 'items'

# %%
###down under

# %%
df3['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3['d'].plot.kde(linestyle='--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3.plot.area()
plt.xlim(0,30)
plt.legend(loc='center right',bbox_to_anchor=(1.15,0.5))

# %%
##plt.style.use('ggplot') **important

# %%
df3[['a','b']].plot.box()  ####IMPORTANT
# Out:
# <AxesSubplot:>
