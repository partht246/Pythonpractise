# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')

# %%
df1 = pd.read_csv('df1',index_col =0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='hist',bins=30) #list what you can call
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha = 0.4) #alpha controls transparency
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar() #takes index values as category, so index should be categorical
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True) #nicer
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.line(x=df1.index,y='B')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\DELLLA~1\AppData\Local\Temp/ipykernel_22664/3397371167.py in <module>
# ----> 1 df1.plot.line(x=df1.index,y='B')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#    1038         as coordinates.
#    1039         """
# -> 1040         return self(kind="line", x=x, y=y, **kwargs)
#    1041
#    1042     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     935                 if is_integer(x) and not data.columns.holds_integer():
#     936                     x = data_cols[x]
# --> 937                 elif not isinstance(data[x], ABCSeries):
#     938                     raise ValueError("x must be a label or position")
#     939                 data = data.set_index(x)
#
# ...

# %%
df1.plot.line(x=df1.index,y='B')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\DELLLA~1\AppData\Local\Temp/ipykernel_22664/3397371167.py in <module>
# ----> 1 df1.plot.line(x=df1.index,y='B')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#    1038         as coordinates.
#    1039         """
# -> 1040         return self(kind="line", x=x, y=y, **kwargs)
#    1041
#    1042     @Appender(
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     935                 if is_integer(x) and not data.columns.holds_integer():
#     936                     x = data_cols[x]
# --> 937                 elif not isinstance(data[x], ABCSeries):
#     938                     raise ValueError("x must be a label or position")
#     939                 data = data.set_index(x)
#
# ...

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm') # a vs b displaying third argument c
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100,color='black',edgecolor='white') # a vs b and size indicates their c value
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns = ['a','b']) #revise the data frame

# %%
df.head()
# Out:
#           a         b
# 0 -0.616827 -0.984893
# 1  0.710298  0.149870
# 2  0.228827 -0.288722
# 3  0.934169  0.004260
# 4  2.159395 -1.783137

# %%
df.plot.hexbin(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
